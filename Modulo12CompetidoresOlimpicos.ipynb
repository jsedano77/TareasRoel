# %% [markdown]
# # Sesión 12 - Competidores Olimpicos

# %% [markdown]
# ##### Crear un programa en Visual Studio que me permita saber cuál es el competidor más veterano que ha recibido medalla (oro, plata o bronce)
# ##### Crear un programa en Visual Studio que me permita saber cuál es el competidor más joven que ha recibido medalla de oro
# ##### Encuentra al competidor más ganador de la historia y crea un csv con toda su información.

# %%
import pandas as pd
import numpy as np
import csv

# %%
datos= pd.read_csv("C:\\Users\\user\\\Documents\\GitHub\\TareasRoel\\athlete_events.csv")

# %%
datos
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
datos["Age"].min()
# Out:
# 10.0

# %%
datos[datos["Age"]==10]
# Out:
#            ID                Name Sex   Age  Height  Weight  \
# 142882  71691  Dimitrios Loundras   M  10.0     NaN     NaN
#
#                                  Team  NOC        Games  Year  Season    City  \
# 142882  Ethnikos Gymnastikos Syllogos  GRE  1896 Summer  1896  Summer  Athina
#
#              Sport                                  Event   Medal
# 142882  Gymnastics  Gymnastics Men's Parallel Bars, Teams  Bronze

# %%
datos["Age"].max()
# Out:
# 97.0

# %%
datos[datos["Age"]==97]datos[datos["Age"]==97]
# Out:
#   Cell In[7], line 1
#     datos[datos["Age"]==97]datos[datos["Age"]==97]
#                            ^
# SyntaxError: invalid syntax

# %%
datosMedalla=datos[((datos["Medal"]=="Gold") | (datos["Medal"]=="Silver")| (datos["Medal"]=="Bronze")) ]

# %% [markdown]
# ### Personas con 3 medallas

# %%
datosMedalla
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 37          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 38          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 40          16             Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 41          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# ...        ...                                  ...  ..   ...     ...     ...
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F  25.0   168.0    80.0
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 271082  135554                         Bogusaw Zych   M  28.0   182.0    82.0
# 271102  135563            Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 271103  135563            Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
#
# ...

# %%
datosMedalla["Name"].value_counts()
# Out:
# Michael Fred Phelps, II               28
# Larysa Semenivna Latynina (Diriy-)    18
# Nikolay Yefimovich Andrianov          15
# Ole Einar Bjrndalen                   13
# Edoardo Mangiarotti                   13
#                                       ..
# Kirill Olegovich Ivanov                1
# Ivan Ivanov Ivanov                     1
# Haralambie Ivanov                      1
# Georgi Ivanov                          1
# Henryk Leliwa-Roycewicz                1
# Name: Name, Length: 28202, dtype: int64

# %% [markdown]
# ### Competidor más veterano

# %%
datosVeterano = datos["Age"].max()

# %%
datosVeterano
# Out:
# 97.0

# %%
datos[datos["Age"]==97]
# Out:
#             ID                    Name Sex   Age  Height  Weight  \
# 257054  128719  John Quincy Adams Ward   M  97.0     NaN     NaN
#
#                  Team  NOC        Games  Year  Season       City  \
# 257054  United States  USA  1928 Summer  1928  Summer  Amsterdam
#
#                    Sport                                        Event Medal
# 257054  Art Competitions  Art Competitions Mixed Sculpturing, Statues   NaN

# %% [markdown]
# ### Competidor más joven que ha recibido medalla de oro

# %%
datosOro=datos[datos["Medal"]=="Gold"]

# %%
datosOro
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 42          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 48          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 60          20                   Kjetil Andr Aamodt   M  20.0   176.0    85.0
# ...        ...                                  ...  ..   ...     ...     ...
# 270981  135503                      Zurab Zviadauri   M  23.0   182.0    90.0
# 271009  135520                          Julia Zwehl   F  28.0   167.0    60.0
# 271016  135523       Ronald Ferdinand "Ron" Zwerver   M  29.0   200.0    93.0
# 271049  135545                      Henk Jan Zwolle   M  31.0   197.0    93.0
# 271076  135553  Galina Ivanovna Zybina (-Fyodorova)   F  21.0   168.0    80.0
#
# ...

# %%
datosOro["Age"].min()
# Out:
# 13.0

# %%
datosOro[datosOro["Age"]==13]
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 27207    14142                       Hans Bourquin   M  13.0     NaN     NaN
# 52010    26731  Donna Elizabeth de Varona (-Pinto)   F  13.0   168.0    61.0
# 73581    37398                          Fu Mingxia   F  13.0   160.0    48.0
# 78544    39866        Marjorie Gestring (-Redlick)   F  13.0     NaN     NaN
# 119277   60384                          Kim Yun-Mi   F  13.0   160.0    48.0
# 200704  100797       Aileen Muriel Riggin (-Soule)   F  13.0   142.0     NaN
# 268602  134381                         Klaus Zerta   M  13.0   165.0    48.0
#
#                  Team  NOC        Games  Year  Season         City  \
# 27207     Switzerland  SUI  1928 Summer  1928  Summer    Amsterdam
# 52010   United States  USA  1960 Summer  1960  Summer         Roma
# 73581           China  CHN  1992 Summer  1992  Summer    Barcelona
# 78544   United States  USA  1936 Summer  1936  Summer       Berlin
# ...

# %% [markdown]
# ## Competidor más ganador de la historia

# %%
datos["Name"].value_counts()
# Out:
# Robert Tait McKenzie            58
# Heikki Ilmari Savolainen        39
# Joseph "Josy" Stoffel           38
# Ioannis Theofilakis             36
# Takashi Ono                     33
#                                 ..
# Tatyana Vasilyevna Kalmykova     1
# Mariya Lvovna Kalmykova          1
# Christine Kalmer                 1
# Joannis "Jannis" Kalmazidis      1
# Pierre-Georges LeClercq          1
# Name: Name, Length: 134732, dtype: int64

# %%
print("Mas Ganador: Robert Tait McKenzie")
# Out:
# Mas Ganador: Robert Tait McKenzie

# %% [markdown]
# # Avanzado

# %% [markdown]
# ### Crear un programa en Visual Studio que me permita saber cuál es e### competidor más veterano que ha recibido medalla para los NOC´s MEX, COL y ARG (oro, plata o bronce)
# ### Crear un programa en Visual Studio que me permita saber cuál es e### competidor más joven que ha recibido medalla de oro para los NOC´s USA y CAN
# ### Encuentra al competidor más ganador de la historia en medallas totales, medallas de oro, medallas de plata y medallas de broce para los NOC´s USA, CHN y RUS.
# ### Crea un csv con toda su información.

# %%
datosPais=datosMedalla[((datosMedalla["NOC"]=="MEX") | (datosMedalla["NOC"]=="COL")| (datosMedalla["Medal"]=="ARG")) ]

# %%
datosPais
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 1173       654           Daniel Aceves Villagrn   M  19.0   158.0    52.0
# 5689      3206              Yuri Alvear Orjuela   F  26.0   176.0    70.0
# 5690      3206              Yuri Alvear Orjuela   F  30.0   176.0    70.0
# 8661      4757    Javier Ignacio Aquino Carmona   M  22.0   165.0    62.0
# 11204     6126           Mariana Avitia Martnez   F  18.0   164.0    61.0
# ...        ...                              ...  ..   ...     ...     ...
# 250719  125576                Fabin Vzquez Lpez   M  37.0   165.0    72.0
# 252440  126410     Nstor Vicente Vidrio Serrano   M  23.0   179.0    69.0
# 266350  133251  Jos Manuel Youshimatz Sotomayor   M  22.0   165.0    56.0
# 267591  133870            Alfonso Zamora Quiroz   M  18.0   160.0    54.0
# 267844  133999            Agustn Zaragoza Reyna   M  27.0   179.0    75.0
#
#             Team  NOC        Games  Year  Season            City  \
# ...

# %%
datosPais["Age"].max()
# Out:
# 44.0

# %%
datosPais[datosPais["Age"]==44]
# Out:
#            ID                                               Name Sex   Age  \
# 64706   33109  Jos Pablo Eustaquio Manuel Francisco Escandn y...   M  44.0
# 156528  78626                           Manuel Mendvil Yocupicio   M  44.0
#
#         Height  Weight                   Team  NOC        Games  Year  Season  \
# 64706      NaN     NaN  A North American Team  MEX  1900 Summer  1900  Summer
# 156528   176.0    68.0                 Mexico  MEX  1980 Summer  1980  Summer
#
#           City          Sport                                      Event  \
# 64706    Paris           Polo                            Polo Men's Polo
# 156528  Moskva  Equestrianism  Equestrianism Mixed Three-Day Event, Team
#
#          Medal
# 64706   Bronze
# 156528  Bronze

# %%
datosPaisOro = datosOro[((datosOro["NOC"]=="USA") | (datosOro["NOC"]=="CAN")) ]

# %%
datosPaisOro["Age"].min()
# Out:
# 13.0

# %%
datosPaisOro[datosPaisOro["Age"]==13]
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 52010    26731  Donna Elizabeth de Varona (-Pinto)   F  13.0   168.0    61.0
# 78544    39866        Marjorie Gestring (-Redlick)   F  13.0     NaN     NaN
# 200704  100797       Aileen Muriel Riggin (-Soule)   F  13.0   142.0     NaN
#
#                  Team  NOC        Games  Year  Season       City     Sport  \
# 52010   United States  USA  1960 Summer  1960  Summer       Roma  Swimming
# 78544   United States  USA  1936 Summer  1936  Summer     Berlin    Diving
# 200704  United States  USA  1920 Summer  1920  Summer  Antwerpen    Diving
#
#                                                   Event Medal
# 52010   Swimming Women's 4 x 100 metres Freestyle Relay  Gold
# 78544                        Diving Women's Springboard  Gold
# 200704                       Diving Women's Springboard  Gold

# %%
datosPaisOro
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 283        150    Margaret Ives Abbott (-Dunne)   F  23.0     NaN     NaN
# 609        351       Julius Shareef Abdur-Rahim   M  23.0   202.0   104.0
# 673        392               George Gordon Abel   M  35.0     NaN     NaN
# 710        404      Louis Grenville "Lou" Abell   M  15.0     NaN     NaN
# 711        404      Louis Grenville "Lou" Abell   M  19.0     NaN     NaN
# ...        ...                              ...  ..   ...     ...     ...
# 266983  133576  Stephen Gregory "Steve" Yzerman   M  36.0   180.0    84.0
# 267204  133685             Mariel Leigh Zagunis   F  19.0   173.0    72.0
# 267205  133685             Mariel Leigh Zagunis   F  23.0   173.0    72.0
# 269922  135045                    Rbert Zimonyi   M  46.0   170.0    52.0
# 270394  135256               Zachary "Zac" Zorn   M  21.0   193.0    86.0
#
#                     Team  NOC        Games  Year  Season            City  \
# ...

# %%
datosPaisOro.to_csv("C:\\Users\\user\\\Documents\\GitHub\\TareasRoel\\salida.csv", header=True, index=True)

# %%
datosJovenOro=datosPaisOro[datosPaisOro["Age"]==13]

# %%
datosJovenOro
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 52010    26731  Donna Elizabeth de Varona (-Pinto)   F  13.0   168.0    61.0
# 78544    39866        Marjorie Gestring (-Redlick)   F  13.0     NaN     NaN
# 200704  100797       Aileen Muriel Riggin (-Soule)   F  13.0   142.0     NaN
#
#                  Team  NOC        Games  Year  Season       City     Sport  \
# 52010   United States  USA  1960 Summer  1960  Summer       Roma  Swimming
# 78544   United States  USA  1936 Summer  1936  Summer     Berlin    Diving
# 200704  United States  USA  1920 Summer  1920  Summer  Antwerpen    Diving
#
#                                                   Event Medal
# 52010   Swimming Women's 4 x 100 metres Freestyle Relay  Gold
# 78544                        Diving Women's Springboard  Gold
# 200704                       Diving Women's Springboard  Gold

# %%
datosPaisOro.to_csv("C:\\Users\\user\\\Documents\\GitHub\\TareasRoel\\salidaOro.csv", header=True, index=True)
